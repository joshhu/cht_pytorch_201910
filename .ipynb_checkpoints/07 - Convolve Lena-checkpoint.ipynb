# %%
import torch
import torchvision.models as models
from torchvision import transforms as T
import PIL.Image as Image
import cv2
from matplotlib import pyplot as plt

imgTensor = T.ToTensor()(Image.open('lena.jpeg'))
imgTensor = imgTensor.unsqueeze(0)
print(imgTensor.shape)
conv2d_1 = torch.nn.Conv2d(in_channels=3, out_channels=1, kernel_size=8)
maxpool = torch.nn.MaxPool2d(1)

# conv2d_2 = torch.nn.Conv2d(in_channels=4, out_channels=5, kernel_size=2)

aa = conv2d_1(imgTensor)
bb = aa
print(bb.shape)
bb = bb.squeeze(0)
bb = T.ToPILImage()(bb)
display(bb)
conv2d_1.weight.shape
# Out:
# torch.Size([1, 3, 382, 728])
# torch.Size([1, 1, 375, 721])
# <PIL.Image.Image image mode=L size=721x375 at 0x7FAC2C03CE10>
# torch.Size([1, 3, 8, 8])

# %%
import numpy as np
a = np.array([[1,2,3],[1,2,3],[1,2,3]])
b = np.array([[4,5,6],[1,2,3],[1,2,3]])
# Out:
#   File "<ipython-input-48-23b9aeb5ff45>", line 4
#     a x b
#       ^
# SyntaxError: invalid syntax
